# %%
import pandas as pd

df = pd.read_csv('CleaningV2.txt', header = 0)
df = pd.read_csv('CleaningV2.txt', names = ['#YY'  ,'MM' ,'DD' ,'hh' ,'mm' ,
'WDIR' ,'WSPD', 'GST' , 'WVHT',  'DPD' ,  'APD' , 'MWD' ,  'PRES' , 'ATMP' , 'WTMP' , 'DEWP' , 'VIS' , 'TIDE'])
# Imports the text file and sets up the column names
df = df.drop(df.index[0:2])
df=df.reset_index(drop=True)
#got rid of useless rows and reset the index back to 0

df= df.astype(float)
#changes all the data to float

df = df[(df.hh >= 6) & (df.hh <= 17)]
df=df.reset_index(drop=True)
#only grabs the hours between 6am - 6pm
df = df[df != 99]
df = df[df!= 999]
df = df.fillna(0)
# removing useless values and replaces them with 0

df = df.groupby(df.index // 36).mean()




df
# Out:
#        #YY   MM    DD    hh    mm        WDIR       WSPD        GST      WVHT  \
# 0   2021.0  1.0   1.0   8.5  25.0  331.944444   8.197222  10.141667  0.115278
# 1   2021.0  1.0   1.0  14.5  25.0  324.027778   3.180556   4.466667  0.088889
# 2   2021.0  1.0   2.0   8.5  25.0   91.416667   8.833333  10.958333  0.164167
# 3   2021.0  1.0   2.0  14.5  25.0  216.333333   8.288889  10.886111  0.260000
# 4   2021.0  1.0   3.0   8.5  25.0  223.611111   5.888889   7.933333  0.292500
# ..     ...  ...   ...   ...   ...         ...        ...        ...       ...
# 57  2021.0  1.0  29.0  14.5  25.0  311.694444  12.341667  16.233333  0.277500
# 58  2021.0  1.0  30.0   8.5  25.0  319.666667   9.344444  12.469444  0.333611
# 59  2021.0  1.0  30.0  14.5  25.0  319.055556   7.430556  10.336111  0.353056
# 60  2021.0  1.0  31.0   8.5  25.0  323.694444   6.083333   8.272222  0.309444
# 61  2021.0  1.0  31.0  14.5  25.0  292.277778   2.555556   4.480556  0.251667
#
# ...
